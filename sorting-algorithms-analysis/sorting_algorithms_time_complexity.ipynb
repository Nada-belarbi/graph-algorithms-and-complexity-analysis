# %%
# Importation des différentes fonctions utiles pour le projet
from sorting_algorithms import *

# %%
sys.setrecursionlimit(10000)

# %% [markdown]
# ---

# %% [markdown]
# # **Théorie de la Complexité des Algorithmes**
#
# ## **Introduction**
# La complexité d'un algorithme est une mesure de l'efficacité de celui-ci en termes de **temps d'exécution** ou d'**espace mémoire** requis, en fonction de la taille de l'entrée. Cette évaluation permet de comparer différents algorithmes pour résoudre un même problème.
#
# ---
#
# ## **Types de Complexités**
# - **Complexité temporelle** (*Time Complexity*) : Mesure le nombre d’opérations élémentaires exécutées en fonction de la taille de l’entrée.
# - **Complexité spatiale** (*Space Complexity*) : Mesure la quantité de mémoire supplémentaire utilisée par l’algorithme.
#
# ---
#
# ## **Notations Asymptotiques**
# Les notations asymptotiques décrivent la croissance de la complexité pour de grandes tailles d'entrée ($n \rightarrow \infty$).
#
# - **O (notation Big-O)** : Représente une borne supérieure. Exemple : $O(n^2)$ signifie que l'algorithme peut être aussi lent que $n^2$ opérations dans le pire cas.
# - **Ω (Omega)** : Représente une borne inférieure. Exemple : $Ω(n)$ signifie qu'au minimum $n$ opérations seront nécessaires.
# - **Θ (Theta)** : Représente une borne exacte. Exemple : $Θ(n^2)$ indique que $n^2$ opérations sont effectuées dans le pire et le meilleur cas.
#
# ---
#
# ## **Cas de Complexité**
# Les algorithmes sont analysés selon trois cas :
# - **Meilleur cas** (*Best Case*) : La performance optimale, souvent rare. Exemple : tableau déjà trié pour **Insertion Sort**.
# - **Pire cas** (*Worst Case*) : Le scénario le plus défavorable. Exemple : tableau trié en ordre décroissant pour **Bubble Sort**.
# - **Cas moyen** (*Average Case*) : Un cas typique basé sur une entrée aléatoire.
#
# ---
#
# ## **Complexité des Algorithmes de Tri**
# Voici un résumé théorique des complexités des algorithmes de tri étudiés dans le projet :
#
# | **Algorithme**      | **Meilleur Cas** | **Cas Moyen**   | **Pire Cas**    | **Complexité Spatiale** | **Stable** | **En Place** |
# |---------------------|------------------|-----------------|-----------------|-------------------------|------------|--------------|
# | **Bubble Sort**    | $O(n)$             | $O(n²)$           | $O(n²)$           | $O(1)$                    | Oui        | Oui          |
# | **Selection Sort** | $O(n²)$           | $O(n²)$           | $O(n²)$           | $O(1)$                    | Non        | Oui          |
# | **Insertion Sort** | $O(n)$            | $O(n²)$           | $O(n²)$           | $O(1)$                    | Oui        | Oui          |
# | **Heap Sort**     | $O(n \log n)$       | $O(n \log n)$     | $O(n \log n)$      | $O(1)$                    | Non        | Oui          |
# | **Quick Sort**      | $O(n \log n)$       | $O(n \log n)$      | $O(n²)$           | $O(n \log n)$                | Non        | Oui          |
# | **Merge Sort**  | $O(n \log n)$      | $O(n \log n)$      | $O(n \log n)$      | $O(n)$                    | Oui        | Non          |
#
#
# ---
#
# ## **Importance de l'Évaluation Empirique**
# - Les complexités théoriques ne prennent pas en compte les optimisations pratiques, comme les caches ou les architectures matérielles.
# - Les tests empiriques complètent les analyses théoriques en illustrant les performances sur des cas concrets.
#
# ---
#
# ## **Applications Pratiques**
# - Choisir l'algorithme adapté au contexte (ex : Quick Sort est rapide pour des petits tableaux, Merge Sort est stable et efficace pour des grandes données avec des besoins de stabilité).

# %% [markdown]
# ---

# %% [markdown]
# # **Étude des complexités :**

# %% [markdown]
# ---

# %% [markdown]
# ## **Bubble Sort**
#
# ### **Description de l'algorithme**
#
# Le Bubble Sort compare les éléments adjacents d'un tableau et les échange si nécessaire, jusqu'à ce que le tableau soit trié. Le processus est répété pour tous les éléments non triés.
#
# ---
#
# ### **Analyse théorique**
#
# #### **Pire cas ($O(n^2)$)** :
# - Lorsqu'un tableau est trié dans l'ordre inverse.
# - Chaque élément doit être comparé avec tous les autres, ce qui donne un nombre total de comparaisons de :
#   $$
#   (n-1) + (n-2) + \dots + 1 = \frac{n(n-1)}{2}
#   $$
#   soit $O(n^2)$.
#
# #### **Meilleur cas ($O(n)$)** :
# - Lorsque le tableau est déjà trié.
# - Une seule passe est nécessaire pour vérifier que tous les éléments sont à leur place.
#
# #### **Cas moyen ($O(n^2)$)** :
# - En supposant des données aléatoires, chaque élément peut nécessiter d’être échangé plusieurs fois, mais le nombre total de comparaisons reste proportionnel à O(n^2).
#
# #### **Complexité spatiale** :
# - **En place** : Utilise $O(1)$ mémoire supplémentaire.
# - **Stable** : Oui, car les éléments égaux conservent leur ordre initial.

# %% [markdown]
# ---

# %% [markdown]
# ### **Code Python : Implémentation de *Bubble Sort***

# %%
def bubble_sort(arr):
    n = len(arr)
    for i in range(n):
        swapped = False
        for j in range(0, n - i - 1):
            if arr[j] > arr[j + 1]:
                arr[j], arr[j + 1] = arr[j + 1], arr[j]  # Échange
                swapped = True
        # Si aucun échange n'a eu lieu, le tableau est trié
        if not swapped:
            break
    return arr

# %% [markdown]
# ---

# %% [markdown]
# ### **Validation empirique**
#
# Nous allons vérifier les temps d'exécution du Bubble Sort sur des tableaux :
#
# 1. **Déjà triés (*Meilleur Cas*)**.
# 2. **Triés dans l'ordre décroissant (*Pire Cas*)**.
# 3. **Avec des valeurs aléatoires (*Cas Moyen*)**.

# %% [markdown]
# ---

# %%
executerTri(bubble_sort,'r','Bubble sort', surplace=False)

# %% [markdown]
# ---

# %% [markdown]
# ### **Analyse du graphique**
#
# #### **Meilleur Cas ($O(n)$)** :
# - La courbe doit croître de manière **linéaire**.
# - Ici, la courbe en tirets semble correcte, car elle reste en bas et augmente proportionnellement à $n$.
#
# #### **Cas Moyen ($O(n^2)$)** :
# - La courbe doit avoir une croissance **quadratique**.
# - La ligne continue reflète bien ce comportement.
#
# #### **Pire Cas ($O(n^2)$)** :
# - Comme pour le cas moyen, la croissance doit être **quadratique**, mais un peu plus élevée car le pire cas nécessite plus d'opérations.
# - La courbe en pointillés semble bien capturer cela.
#
# ### **Conclusion**
#
# Les résultats empiriques obtenus dans le graphique sont cohérents avec les analyses théoriques des complexités des cas :
#
# 1. **Meilleur Cas ($O(n)$)** :
#    - Le temps d'exécution est linéaire lorsque les données sont déjà triées, comme prévu théoriquement.
#    - La courbe en tirets illustre cette performance optimale.
#
# 2. **Cas Moyen ($O(n^2)$)** :
#    - La courbe continue suit une tendance quadratique, ce qui reflète bien la complexité théorique dans un scénario aléatoire.
#
# 3. **Pire Cas ($O(n^2)$)** :
#    - La courbe en pointillés montre une croissance quadratique plus élevée, en accord avec le pire cas où le nombre maximum d'opérations est requis.
#
# ### **Interprétation générale** :
# - Le **Bubble Sort** est un algorithme simple mais inefficace pour des grands tableaux, en raison de sa complexité quadratique ($O(n^2)$) dans la plupart des cas.
# - Il est performant uniquement pour des tableaux presque triés ou de petite taille.

# %% [markdown]
# ---

# %% [markdown]
# ## **Selection Sort**
#
# ### **Description de l'algorithme**
#
# Le **Selection Sort** divise le tableau en deux parties : une sous-liste triée (à gauche) et une sous-liste non triée (à droite). À chaque itération, il identifie le plus petit élément de la sous-liste non triée et l'échange avec le premier élément de cette sous-liste. Ce processus se répète jusqu'à ce que tout le tableau soit trié.
#
# ---
#
# ### **Analyse théorique**
#
# #### **Pire cas ($O(n^2)$)** :
# - Chaque élément doit être comparé avec tous les autres dans la sous-liste non triée.
# - Le nombre total de comparaisons est :
#   $$
#   (n-1) + (n-2) + \dots + 1 = \frac{n(n-1)}{2}
#   $$
#   soit \($O(n^2)$\).
#
# #### **Meilleur cas ($O(n^2)$)** :
# - Contrairement à d'autres algorithmes comme le Bubble Sort, le **Selection Sort** effectue toujours le même nombre de comparaisons, même si le tableau est déjà trié.
#
# #### **Cas moyen ($O(n^2)$)** :
# - En supposant des données aléatoires, le nombre total de comparaisons reste le même qu'en pire cas, soit $O(n^2)$.
#
# ---
#
# ### **Complexité spatiale** :
# - **En place** : Utilise $O(1)$ mémoire supplémentaire.
# - **Stable** : Non, car des éléments égaux peuvent changer d'ordre lors de l'échange.

# %% [markdown]
# ---

# %% [markdown]
# ### **Code Python : Implémentation de *Selection Sort***

# %%
def selection_sort(arr):
    n = len(arr)
    for i in range(n):
        # Trouver l'indice du plus petit élément dans la sous-liste non triée
        min_index = i
        for j in range(i+1, n):
            if arr[j] < arr[min_index]:
                min_index = j
        # Échanger le plus petit élément avec le premier élément non trié
        arr[i], arr[min_index] = arr[min_index], arr[i]
    return arr

# %% [markdown]
# ---

# %% [markdown]
# ### **Validation empirique**
#
# Nous allons vérifier les temps d'exécution du Selection Sort sur des tableaux :
#
# 1. **Déjà triés (*Meilleur Cas*)**.
# 2. **Triés dans l'ordre décroissant (*Pire Cas*)**.
# 3. **Avec des valeurs aléatoires (*Cas Moyen*)**.

# %% [markdown]
# ---

# %%
executerTri(selection_sort, color='b', nom='Selection Sort', surplace=False)

# %% [markdown]
# ---

# %% [markdown]
# ### **Analyse du graphique**
#
# #### **Meilleur cas $(O(n^2))$** :
# - Le Selection Sort effectue toujours $(O(n^2))$ comparaisons, même si le tableau est déjà trié.
# - Cela correspond à la courbe en tirets bleus, qui suit une croissance quadratique.
#
# #### **Cas moyen $(O(n^2))$** :
# - Pour des données aléatoires, la complexité reste $(O(n^2))$.
# - La courbe en trait continu reflète bien ce comportement quadratique.
#
# #### **Pire cas $(O(n^2))$** :
# - Le pire cas implique également $(O(n^2))$ comparaisons.
# - La courbe en pointillés suit la même tendance quadratique, légèrement au-dessus des autres courbes, ce qui est attendu.
#
# ---
#
# ### **Conformité des résultats**
#
# #### **Comparaison des cas** :
# - Les trois courbes (meilleur cas, cas moyen, pire cas) sont proches les unes des autres, ce qui est conforme à la théorie puisque la complexité est identique dans tous les cas $O(n^2)$\.
#
# #### **Croissance quadratique** :
# - Les courbes montrent une croissance quadratique, ce qui est attendu pour cet algorithme.
#
# ---
#
# ### **Conclusion**
#
# Le graphique est conforme aux attentes pour le **Selection Sort**. Il montre que l'algorithme est peu efficace pour des tableaux de grande taille, car sa complexité reste $O(n^2)$ dans tous les cas.

# %% [markdown]
# ---

# %% [markdown]
# ## **Insertion Sort**
#
# L'**Insertion Sort** est un algorithme simple et efficace pour trier de petites collections ou des données déjà partiellement triées.
#
# ---
#
# ### **Description de l'algorithme**
#
# L'**Insertion Sort** parcourt le tableau à trier en construisant progressivement une sous-liste triée. À chaque itération, il extrait un élément de la partie non triée et l'insère à la position appropriée dans la partie triée. Ce processus se répète jusqu'à ce que tous les éléments soient triés.
#
# ---
#
# ### **Analyse théorique**
#
# #### **Meilleur cas ($O(n)$)**
# - **Scénario** : Le tableau est déjà trié.
# - **Comportement** : L'algorithme parcourt le tableau une seule fois sans effectuer de décalages, réalisant $n-1$ comparaisons.
# - **Complexité** : Linéaire, soit $O(n)$.
#
# #### **Cas moyen ($O(n^2)$)**
# - **Scénario** : Les éléments sont disposés de manière aléatoire.
# - **Comportement** : En moyenne, chaque nouvel élément est comparé à la moitié des éléments de la sous-liste triée, entraînant un nombre total de comparaisons et de déplacements proportionnel à $n^2 / 4$.
# - **Complexité** : Quadratique, soit $O(n^2)$.
#
# #### **Pire cas ($O(n^2)$)**
# - **Scénario** : Le tableau est trié dans l'ordre inverse.
# - **Comportement** : Chaque insertion nécessite de comparer et de déplacer tous les éléments déjà triés, résultant en environ $n^2 / 2$ comparaisons et déplacements.
# - **Complexité** : Quadratique, soit $O(n^2)$.
#
# ---
#
# ### **Complexité spatiale**
#
# - **En place** : Oui, l'algorithme utilise une quantité constante de mémoire supplémentaire, soit $O(1)$.
# - **Stable** : Oui, il préserve l'ordre relatif des éléments égaux.

# %% [markdown]
# ---

# %% [markdown]
# ### **Code Python : Implémentation d'*Insertion Sort***

# %%
def insertion_sort(tableau):
    for i in range(1, len(tableau)):
        cle = tableau[i]
        j = i - 1
        while j >= 0 and cle < tableau[j]:
            tableau[j + 1] = tableau[j]
            j -= 1
        tableau[j + 1] = cle
    return tableau

# %% [markdown]
# ---

# %% [markdown]
# ### **Validation empirique**
#
# Nous allons vérifier les temps d'exécution d'Insertion Sort sur des tableaux :
#
# 1. **Déjà triés (*Meilleur Cas*)**.
# 2. **Triés dans l'ordre décroissant (*Pire Cas*)**.
# 3. **Avec des valeurs aléatoires (*Cas Moyen*)**.

# %% [markdown]
# ---

# %%
executerTri(insertion_sort, color='g', nom='Insertion Sort', surplace=False)

# %% [markdown]
# ---

# %% [markdown]
# ### **Analyse du graphique**
#
# #### **Meilleur cas ($O(n)$)** :
# - **Scénario attendu** : Si le tableau est déjà trié, chaque élément est comparé une seule fois, sans nécessiter de décalages.
# - **Observation** : La courbe en tirets (meilleur cas) est linéaire et reste en bas du graphique, ce qui correspond à une complexité $O(n)$.
#
# #### **Cas moyen ($O(n^2)$)** :
# - **Scénario attendu** : Pour des données aléatoires, chaque nouvel élément est comparé à environ la moitié des éléments déjà triés, entraînant une complexité quadratique.
# - **Observation** : La courbe continue (cas moyen) reflète une croissance quadratique, ce qui est conforme.
#
# #### **Pire cas ($O(n^2)$)** :
# - **Scénario attendu** : Si le tableau est trié dans l'ordre inverse, chaque insertion nécessite de décaler tous les éléments, ce qui entraîne une complexité quadratique.
# - **Observation** : La courbe en pointillés (pire cas) est bien au-dessus des autres courbes et suit une croissance quadratique plus marquée, ce qui est attendu.
#
# ---
#
# ### **Conformité des résultats**
#
# #### **Comparaison des cas** :
# - Les trois courbes montrent des différences nettes, avec le pire cas au-dessus, le cas moyen au milieu, et le meilleur cas en bas.
# - Cela correspond parfaitement aux analyses théoriques des complexités.
#
# #### **Croissance quadratique** :
# - Les courbes pour le cas moyen et le pire cas montrent une croissance quadratique claire, cohérente avec la théorie.
#
# ---
#
# ### **Conclusion**
#
# Le graphique est conforme aux attentes pour l'**Insertion Sort** :
# - Il montre clairement la performance supérieure dans le meilleur cas ($O(n)$) pour des tableaux triés.
# - Il met en évidence la faible efficacité pour des tableaux de grande taille ou triés dans l'ordre inverse, avec une complexité quadratique ($O(n^2)$).

# %% [markdown]
# ---

# %% [markdown]
# ## **Heap Sort**
#
# Le **Heap Sort** est un algorithme de tri par comparaison qui utilise une structure de données appelée tas binaire. Il est particulièrement efficace pour trier de grandes collections de données en raison de sa complexité en temps garantie.
#
# ---
#
# ### **Description de l'algorithme**
#
# Le **Heap Sort** fonctionne en deux phases principales :
#
# 1. **Construction du tas** :
#    Le tableau est transformé en un tas binaire maximal, où chaque parent est supérieur ou égal à ses enfants. Cette étape organise les données de manière à ce que le plus grand élément se trouve à la racine du tas.
#
# 2. **Extraction et tri** :
#    On échange la racine du tas avec le dernier élément du tableau, réduisant ainsi la taille du tas considéré. Ensuite, on rétablit la propriété de tas maximal sur la portion restante. Ce processus est répété jusqu'à ce que tous les éléments soient extraits, produisant un tableau trié.
#
# ---
#
# ### **Analyse théorique**
#
# #### **Complexité en temps**
#
# - **Pire cas (\($O(n \log n)$\))** :
#   Dans tous les scénarios, y compris le pire cas, le **Heap Sort** effectue \($O(n \log n)$\) opérations.
#   La construction initiale du tas prend \($O(n)$\) temps, et chaque extraction suivie d'un réajustement du tas prend \($O(\log n)$\), répétée \($n$\) fois.
#
# - **Meilleur cas (\($O(n \log n)$\))** :
#   Même si le tableau est déjà trié, le **Heap Sort** n'en tient pas compte et suit le même processus, résultant en une complexité de \($O(n \log n)$\).
#
# - **Cas moyen (\($O(n \log n)$\))** :
#   Pour des données aléatoires, le comportement reste cohérent avec une complexité de \($O(n \log n)$\).
#
# ---
#
# ### **Complexité spatiale**
#
# - **En place** :
#   Oui, le **Heap Sort** trie le tableau sans nécessiter de mémoire supplémentaire significative, soit \($O(1)$\).
#
# - **Stable** :
#   Non, le **Heap Sort** n'est pas stable, ce qui signifie que l'ordre relatif des éléments égaux peut être modifié.

# %% [markdown]
# ---

# %% [markdown]
# ### **Code Python : Implémentation du *Heap Sort***

# %%
def heapify(arr, n, i):
    """
    Fonction pour transformer un sous-arbre en un tas binaire maximal.
    :param arr: Liste représentant le tableau.
    :param n: Taille du tas.
    :param i: Index de l'élément à heapifier.
    """
    largest = i  # Initialiser le plus grand comme racine
    left = 2 * i + 1  # Fils gauche
    right = 2 * i + 2  # Fils droit

    # Vérifier si le fils gauche existe et est plus grand que la racine
    if left < n and arr[i] < arr[left]:
        largest = left

    # Vérifier si le fils droit existe et est plus grand que le plus grand actuel
    if right < n and arr[largest] < arr[right]:
        largest = right

    # Changer la racine si nécessaire
    if largest != i:
        arr[i], arr[largest] = arr[largest], arr[i]  # Échanger

        # Heapifier le sous-arbre affecté
        heapify(arr, n, largest)

def heap_sort(arr):
    """
    Fonction pour effectuer le tri par tas sur un tableau.
    :param arr: Liste représentant le tableau à trier.
    """
    n = len(arr)

    # Construire un tas maximal
    for i in range(n // 2 - 1, -1, -1):
        heapify(arr, n, i)

    # Extraire les éléments un par un du tas
    for i in range(n - 1, 0, -1):
        arr[i], arr[0] = arr[0], arr[i]  # Échanger
        heapify(arr, i, 0)

# %% [markdown]
# ---

# %% [markdown]
# ### **Validation empirique**
#
# Nous allons vérifier les temps d'exécution du Heap Sort sur des tableaux :
#
# 1. **Déjà triés (*Meilleur Cas*)**.
# 2. **Triés dans l'ordre décroissant (*Pire Cas*)**.
# 3. **Avec des valeurs aléatoires (*Cas Moyen*)**.

# %% [markdown]
# ---

# %%
executerTri(heap_sort, color='y', nom='Heap Sort')

# %% [markdown]
# ---

# %% [markdown]
# ### **Analyse du graphique**
#
# #### **Meilleur cas ($O(n \log n)$)** :
# - **Scénario attendu** : Même si le tableau est déjà trié, le Heap Sort suit le même processus et conserve une complexité de $O(n \log n)$.
# - **Observation** : La courbe en tirets (meilleur cas) suit une croissance logarithmique par rapport à la taille du tableau, ce qui correspond aux attentes.
#
# #### **Cas moyen ($O(n \log n)$)** :
# - **Scénario attendu** : Pour des données aléatoires, le Heap Sort présente également une complexité de $O(n \log n)$.
# - **Observation** : La courbe continue (cas moyen) reflète une croissance logarithmique conforme.
#
# #### **Pire cas ($O(n \log n)$)** :
# - **Scénario attendu** : Dans le pire cas, le Heap Sort effectue également $O(n \log n)$ opérations, car il ne dépend pas de l'ordre initial des données.
# - **Observation** : La courbe en pointillés (pire cas) suit une croissance logarithmique par rapport à la taille du tableau, ce qui correspond aux attentes.
#
# ---
#
# ### **Conformité des résultats**
#
# #### **Croissance logarithmique** :
# - Les trois courbes montrent une croissance proportionnelle à $O(n \log n)$, ce qui est attendu pour le Heap Sort.
#
# #### **Comparaison des cas** :
# - Les courbes pour le meilleur cas, le cas moyen et le pire cas sont très proches, ce qui est normal, car le Heap Sort a une complexité similaire dans tous les scénarios.
#
# #### **Axes et unités** :
# - L'axe $x$ (taille du tableau) et l'axe $y$ (temps d'exécution en millisecondes) montrent des résultats cohérents avec les performances attendues de cet algorithme.
#
# ---
#
# ### **Conclusion**
#
# Le graphique confirme que le **Heap Sort** est un algorithme efficace avec une complexité $O(n \log n)$ dans tous les cas :
# - Il ne bénéficie pas d'un tableau déjà trié (meilleur cas).
# - Il est robuste et offre des performances stables, indépendamment de l'ordre initial des données.
# - Ce tracé valide l'analyse théorique et les performances empiriques du Heap Sort.

# %% [markdown]
# ---

# %% [markdown]
# ## **Quick Sort**
#
# Le **Quick Sort** (ou tri rapide) est un algorithme de tri efficace qui suit le paradigme "diviser pour régner". Voici une description détaillée de son fonctionnement et de sa complexité :
#
# ---
#
# ### **Description de l'algorithme**
#
# Le Quick Sort trie un tableau en suivant ces étapes :
#
# 1. **Choix du pivot** :
#    Un élément du tableau est sélectionné comme pivot. Le choix du pivot peut varier : premier élément, dernier élément, élément aléatoire ou médiane.
#
# 2. **Partitionnement** :
#    Le tableau est réorganisé de manière à ce que tous les éléments inférieurs au pivot soient placés avant celui-ci, et tous les éléments supérieurs après.
#
# 3. **Récursion** :
#    Les sous-tableaux résultants (à gauche et à droite du pivot) sont triés récursivement en répétant les étapes précédentes.
#
# Ce processus se poursuit jusqu'à ce que les sous-tableaux soient réduits à une taille triviale (un ou zéro élément), ce qui signifie qu'ils sont déjà triés.
#
# ---
#
# ### **Analyse théorique**
#
# #### **Pire cas ($O(n^2)$)**
# - **Scénario** :
#   Le pire cas survient lorsque le pivot choisi est systématiquement le plus grand ou le plus petit élément, entraînant des partitions très déséquilibrées.
# - **Comportement** :
#   Cela conduit à une profondeur de récursion maximale, avec un nombre total de comparaisons proportionnel à $n^2$.
#
# #### **Meilleur cas ($O(n \log n)$)**
# - **Scénario** :
#   Le meilleur cas se produit lorsque chaque pivot divise le tableau en deux parties égales ou presque égales.
# - **Comportement** :
#   La profondeur de récursion est alors $O(\log n)$, avec $O(n)$ comparaisons à chaque niveau, résultant en une complexité totale de $O(n \log n)$.
#
# #### **Cas moyen ($O(n \log n)$)**
# - **Scénario** :
#   Pour des données aléatoires, le Quick Sort a une complexité moyenne de $O(n \log n)$.
# - **Comportement** :
#   En moyenne, les partitions sont suffisamment équilibrées pour assurer cette complexité.
#
# ---
#
# ### **Complexité spatiale**
#
# - **En place** :
#   Oui, le Quick Sort trie le tableau en utilisant une quantité constante de mémoire supplémentaire, soit $O(1)$.
#
# - **Stable** :
#   Non, le Quick Sort n'est pas stable, ce qui signifie que l'ordre relatif des éléments égaux peut être modifié.

# %% [markdown]
# ---

# %% [markdown]
# ### **Code Python : Implémentation du *Quick Sort***

# %%
def quick_sort_in_place(arr, low, high):
    """Quick Sort algorithm (in-place)."""
    if low < high:
        pi = partition(arr, low, high) 
        quick_sort_in_place(arr, low, pi - 1)
        quick_sort_in_place(arr, pi + 1, high)

def partition(arr, low, high):
    """Partition function for Quick Sort."""
    pivot = arr[high]  
    i = low - 1  
    for j in range(low, high):
        if arr[j] <= pivot: 
            i += 1
            arr[i], arr[j] = arr[j], arr[i] 
    arr[i + 1], arr[high] = arr[high], arr[i + 1] 
    return i + 1

# %% [markdown]
# ---

# %% [markdown]
# ### **Validation empirique**
#
# Nous allons vérifier les temps d'exécution du Quick Sort sur des tableaux :
#
# 1. **Déjà triés (*Meilleur Cas*)**.
# 2. **Triés dans l'ordre décroissant (*Pire Cas*)**.
# 3. **Avec des valeurs aléatoires (*Cas Moyen*)**.

# %%
executerTri_quick_sort(quick_sort_in_place, color='p', nom='Quick Sort', nlist=10, nval=100)

# %% [markdown]
# ### **Analyse du graphique**
#
# #### **Meilleur cas $(O(n \log n))$** :
# - **Scénario attendu** : Si le tableau est déjà trié, le Quick Sort suit le même processus avec une complexité logarithmique.
# - **Observation** : La courbe en tirets (meilleur cas) est quasi constante et linéaire à petite échelle, ce qui correspond aux attentes.
#
# #### **Cas moyen $(O(n \log n))$** :
# - **Scénario attendu** : Pour des données aléatoires, le Quick Sort a une complexité moyenne logarithmique.
# - **Observation** : La courbe continue (cas moyen) reflète une croissance cohérente avec une complexité $(O(n \log n))$.
#
# #### **Pire cas $(O(n^2))$** :
# - **Scénario attendu** : Dans le pire cas, si le pivot divise mal le tableau, le Quick Sort peut atteindre une complexité quadratique.
# - **Observation** : La courbe en pointillés (pire cas) présente une forte croissance, plus marquée que les deux autres, ce qui est conforme aux attentes théoriques.
#
# ---
#
# ### **Conformité des résultats**
#
# #### **Croissance logarithmique** :
# - La courbe pour le cas moyen $O(n \log n)$ montre une croissance proportionnelle à $n \log n$, comme attendu pour le Quick Sort.
#
# #### **Comparaison des cas** :
# - Les courbes du meilleur cas et du cas moyen sont proches et montrent des performances conformes.
# - La courbe du pire cas est significativement au-dessus, ce qui est attendu lorsque la complexité atteint $O(n^2)$.
#
# #### **Axes et unités** :
# - L'axe $x$ (taille du tableau) et l'axe $y$ (temps d'exécution en millisecondes) montrent des résultats cohérents avec les performances attendues de cet algorithme.
#
# ---
#
# ### **Conclusion**
#
# Le graphique confirme que le **Quick Sort** est un algorithme efficace, particulièrement pour le cas moyen $O(n \log n)$. Cependant, son efficacité diminue dans le pire cas $O(n^2)$, mettant en évidence l'importance du choix du pivot. Ce tracé valide l'analyse théorique et les performances empiriques du Quick Sort.

# %% [markdown]
# ## **Merge Sort**
#
# ### **Description de l'algorithme**
#
# Merge Sort divise récursivement le tableau en deux moitiés, trie chaque moitié, puis fusionne les sous-tableaux triés pour produire le tableau final trié.
#
# ---
#
# ### **Analyse théorique**
#
# #### **Complexité temporelle $(O(n \log n))$** :
# La complexité est la même pour les trois cas (meilleur, pire et moyen), car l'algorithme effectue toujours les mêmes étapes, indépendamment de l'ordre initial des éléments.
#
# 1. **Division** :
#    - Le tableau est divisé récursivement en deux moitiés.
#    - Cela génère $log n$ niveaux, car chaque division réduit la taille du tableau de moitié.
#
# 2. **Fusion** :
#    - À chaque niveau, les sous-tableaux sont fusionnés, ce qui nécessite $n$ opérations pour comparer et réorganiser tous les éléments.
#
# **Conclusion** : La complexité temporelle de Merge Sort est uniforme et vaut $O(n \log n)$ pour tous les cas.
#
# ---
#
# #### **Complexité spatiale $(O(n))$** :
# - Merge Sort utilise $O(n)$ de mémoire supplémentaire pour stocker les sous-tableaux temporaires nécessaires pendant la fusion.
# - L'algorithme est **stable**, car les éléments égaux conservent leur ordre initial dans le tableau trié.
#
#
# ### **Code Python : Implémentation de Merge Sort**

# %%
def merge_sort(arr):
    if len(arr) > 1:
        # Diviser le tableau en deux moitiés
        mid = len(arr) // 2
        left_half = arr[:mid]
        right_half = arr[mid:]

        # Appels récursifs pour chaque moitié
        merge_sort(left_half)
        merge_sort(right_half)

        # Fusion des deux moitiés triées
        i = j = k = 0

        # Comparer et fusionner les éléments des moitiés
        while i < len(left_half) and j < len(right_half):
            if left_half[i] < right_half[j]:
                arr[k] = left_half[i]
                i += 1
            else:
                arr[k] = right_half[j]
                j += 1
            k += 1

        # Ajouter les éléments restants de la moitié gauche
        while i < len(left_half):
            arr[k] = left_half[i]
            i += 1
            k += 1

        # Ajouter les éléments restants de la moitié droite
        while j < len(right_half):
            arr[k] = right_half[j]
            j += 1
            k += 1

# %% [markdown]
# ### **Validation empirique**
#
# Nous allons vérifier les temps d'exécution du Merge Sort sur des tableaux :
#
# 1. **Déjà triés (*Meilleur Cas*)**.
# 2. **Triés dans l'ordre décroissant (*Pire Cas*)**.
# 3. **Avec des valeurs aléatoires (*Cas Moyen*)**.

# %%
executerTri(merge_sort,'r','Bubble sort')

# %% [markdown]
# ### **Analyse du graphique**
#
# #### **Meilleur Cas $(O(n \log n))$** :
# - La courbe pour le meilleur cas suit une **croissance logarithmique linéaire**, car même pour un tableau trié, Merge Sort effectue toutes les étapes de division et de fusion.
# - La courbe illustre cette complexité en étant proche des deux autres, car l'algorithme est déterministe.
#
# #### **Cas Moyen $(O(n \log n))$** :
# - Le cas moyen présente également une **croissance logarithmique linéaire**, car la répartition aléatoire des données n'affecte pas le comportement de l'algorithme.
# - La courbe suit une tendance similaire aux deux autres, ce qui est attendu.
#
# #### **Pire Cas $(O(n \log n))$** :
# - Le pire cas montre une croissance **logarithmique linéaire**, car Merge Sort ne change pas son comportement en fonction de l'ordre initial des données.
# - La courbe est presque identique à celle du meilleur et du cas moyen.
#
# ---
#
# ### **Conclusion**
#
# Les résultats empiriques obtenus dans le graphique sont cohérents avec l'analyse théorique de la complexité de Merge Sort :
#
# 1. **Uniformité des courbes** :
#    - Comme attendu, les trois cas (meilleur, moyen, pire) ont des courbes similaires, car Merge Sort effectue toujours $O(n \log n)$ opérations, indépendamment de l'ordre des données.
#
# 2. **Performance globale** :
#    - Merge Sort est un algorithme efficace pour trier des tableaux de toutes tailles et ordres initiaux.
#    - Contrairement à des algorithmes comme Bubble Sort ou Quick Sort, sa complexité est prévisible et constante dans tous les cas.
#
# ### **Interprétation générale** :
# - Le **Merge Sort** est un algorithme stable et efficace, particulièrement adapté aux tableaux de grande taille grâce à sa complexité uniforme $O(n \log n)$.
# - Le graphique confirme que l'algorithme ne dépend pas de l'ordre initial des données, ce qui en fait une solution robuste.

# %% [markdown]
# ---

# %% [markdown]
# # **Comparaison des Algorithmes de Tri**

# %% [markdown]
# ---

# %% [markdown]
# #### **Bubble Sort** :
# - **Meilleur Cas** : Dans le meilleur cas, Bubble Sort est légèrement plus rapide mais reste inefficace comparé aux autres algorithmes.
# - **Cas Moyen** : Il est très lent dans le cas moyen, où le temps d'exécution augmente rapidement avec la taille du tableau.
# - **Pire Cas** : Le pire cas est également très mauvais, avec une croissance rapide du temps d'exécution. Cet algorithme est à éviter pour des tableaux volumineux.
#
# #### **Selection Sort** :
# - **Meilleur Cas** : Selection Sort est plus rapide que Bubble Sort mais reste loin d’être optimal.
# - **Cas Moyen** : Le temps d'exécution est stable entre les différents cas, mais il est encore relativement lent.
# - **Pire Cas** : Similaire au cas moyen, l'algorithme est stable mais peu performant.
#
# #### **Insertion Sort** :
# - **Meilleur Cas** : Très performant lorsque le tableau est déjà trié ou presque trié.
# - **Cas Moyen** : Plus rapide que Bubble Sort et Selection Sort dans la plupart des cas.
# - **Pire Cas** : Devient lent pour les tableaux inversés, où il doit effectuer beaucoup de comparaisons et d'échanges.
#
# #### **Heap Sort** :
# - **Meilleur Cas** : Le Heap Sort est très efficace et rapide dans le meilleur cas.
# - **Cas Moyen** : Il est stable et affiche les meilleurs temps d'exécution comparé aux autres algorithmes.
# - **Pire Cas** : Même dans le pire cas, Heap Sort reste bien plus rapide que Bubble Sort, Selection Sort et Insertion Sort.
#
# #### **Quick Sort** :
# - **Meilleur Cas** : Quick Sort est extrêmement rapide dans le meilleur cas, notamment lorsque le pivot est bien choisi.
# - **Cas Moyen** : Présente une croissance logarithmique linéaire similaire au meilleur cas, ce qui en fait un des algorithmes de tri les plus performants.
# - **Pire Cas** : Dans le pire cas, ce qui se produit lorsque le pivot choisi est extrémement déséquilibré (par exemple, le plus petit ou le plus grand élément du tableau).
#
#
# #### **Merge Sort** :
# - **Meilleur Cas** :Merge Sort est stable et performant même lorsque le tableau est déjà trié.
# - **Cas Moyen** : l'algorithme effectue toutes les étapes de division et de fusion, indépendamment de l'ordre initial.
# - **Pire Cas** : Identique au cas moyen et au meilleur cas, car Merge Sort suit une logique de division et fusion constante.
#
#
# ---
#
# ### **Conclusion**
#
# 1. **Uniformité des Performances** :
#    - Le **Heap Sort**, le **Quick Sort**, et le **Merge Sort** sont les plus stables et efficaces dans la majorité des cas.
#    - L’**Insertion Sort** est une bonne option pour les tableaux presque triés ou de petite taille.
#
# 2. **Algorithmes à éviter** :
#    - **Bubble Sort** et **Selection Sort** sont surtout pédagogiques et ne sont pas adaptés à des applications réelles nécessitant des performances optimales.
#
# 3. **Merge Sort** :
#    - Particulièrement utile pour les applications nécessitant un tri stable et prévisible.
#
# 4. **Quick Sort** :
#    - Extrêmement rapide dans le meilleur et cas moyen, mais peut être inefficace dans le pire cas si le pivot est mal choisi.
#
# ### **Interprétation Générale** :
# - Le **Heap Sort**, le **Quick Sort**, et le **Merge Sort** sont à privilégier pour les tableaux de grande taille.
# - Le **Insertion Sort** peut être choisi dans des cas spécifiques comme des tableaux déjà triés.
# - Les autres algorithmes sont utiles pour l’apprentissage mais peu adaptés pour un usage en production.

# %% [markdown]
# ---

# %% [markdown]
# # **Explication des résultats**

# %% [markdown]
# ---

# %% [markdown]
# ## **Bubble Sort**
# - **Observation** : Les trois cas (meilleur, moyen, pire) ont des temps d'exécution très proches, avec une croissance quadratique.
# - **Analyse** : Le Bubble Sort effectue toujours $O(n^2)$ comparaisons, peu importe l'état initial du tableau. Son inefficacité pour des tableaux de grande taille est confirmée par les courbes.
#
# ---
#
# ## **Selection Sort**
# - **Observation** : Les courbes pour le meilleur, le pire et le cas moyen sont presque identiques, montrant une croissance quadratique constante.
# - **Analyse** : Le Selection Sort effectue systématiquement $O(n^2)$ comparaisons, car chaque élément est sélectionné indépendamment de l'ordre initial des données.
#
# ---
#
# ## **Insertion Sort**
# - **Observation** :
#   - Une nette distinction entre le meilleur cas $O(n)$ et les autres cas $O(n^2)$.
#   - Le meilleur cas est beaucoup plus rapide lorsque le tableau est déjà trié.
# - **Analyse** : L'Insertion Sort est efficace pour des tableaux déjà triés ou presque triés, mais devient inefficace pour des tableaux de grande taille ou désordonnés.
#
# ---
#
# ## **Heap Sort**
# - **Observation** : Les courbes montrent une croissance proportionnelle à $O(n \log n)$ pour tous les cas.
# - **Analyse** : Le Heap Sort offre des performances stables, peu importe l'ordre initial des données. Cependant, son implémentation en place peut entraîner des accès mémoire moins optimaux, ce qui explique ses temps légèrement plus élevés par rapport au Quick Sort dans certains cas.
#
# ---
#
# ## **Quick Sort**
# - **Observation** :
#   - Meilleur et cas moyen : croissance logarithmique conforme à $O(n \log n)$.
#   - Pire cas : une croissance quadratique $O(n^2)$.
# - **Analyse** : Le Quick Sort est très efficace pour des données aléatoires ou déjà partiellement triées grâce à son comportement $O(n \log n)$. Cependant, un mauvais choix de pivot (comme dans le pire cas) peut entraîner des partitions déséquilibrées et une performance dégradée.
#
# ---
#
# ## **Merge Sort**
# - **Observation** : Les courbes montrent une croissance proportionnelle à $O(n \log n)$ pour tous les cas.
# - **Analyse** : Le Merge Sort offre une performance stable et efficace, quelle que soit la configuration initiale des données. En revanche, sa complexité spatiale $O(n)$ peut être un désavantage par rapport aux algorithmes en place comme le Quick Sort ou le Heap Sort.

# %% [markdown]
# ---

# %% [markdown]
# # **Règles de Bonnes Pratiques**

# %% [markdown]
# ---

# %% [markdown]
# 1. **Choisir l'algorithme selon le cas d'utilisation** :
#    - Utilisez **Quick Sort** ou **Merge Sort** pour des grandes quantités de données.
#    - Préférez **Insertion Sort** pour des petits tableaux ou presque triés.
#
# 2. **Stabilité des données** :
#    - Si la stabilité est importante (l'ordre des éléments égaux doit être préservé), utilisez **Merge Sort**.
#
# 3. **Gérer le pire cas** :
#    - Prenez garde au **Quick Sort** si le choix du pivot n’est pas bien optimisé, car il peut devenir inefficace dans certains cas.
#
# 4. **Minimiser les ressources** :
#    - Évitez les algorithmes comme **Bubble Sort** et **Selection Sort** qui consomment plus de temps et de ressources.
#
# 5. **Testez selon les besoins réels** :
#    - Expérimentez plusieurs algorithmes sur vos données pour vérifier lequel est le plus adapté dans votre contexte.
#
# 6. **Priorisez les algorithmes modernes** :
#    - Dans les systèmes actuels, les algorithmes comme **Heap Sort** et **Merge Sort** sont souvent implémentés p
